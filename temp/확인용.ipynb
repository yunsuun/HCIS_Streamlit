# %%
# ============================================================
# 분석 라이브러리
import pandas as pd
import numpy as np

# 시각화 라이브러리
import matplotlib.pyplot as plt
import seaborn as sns

# 한글, 음수부호 깨짐 방지
import platform
import matplotlib as mpl

if platform.system() == 'Windows': # Windows OS
    plt.rcParams['font.family'] = 'Malgun Gothic'
    mpl.rc('font', family='Malgun Gothic')
elif platform.system() == 'Darwin':  # mac OS
    plt.rcParams['font.family'] = 'AppleGothic'
    mpl.rc('font', family='AppleGothic')
else:  # Linux
    plt.rcParams['font.family'] = 'NanumGothic'
    mpl.rc('font', family='NanumGothic')

# %matplotlib inline

mpl.rc('axes', unicode_minus=False) # 축의 음수 부호를 깨지지 않게 설정

# describe시 자연상수 찍히는 것 방지
pd.set_option('display.float_format', '{:.4f}'.format)

# 출력할 최대 행 수를 'None'으로 설정하여 제한을 없앱니다.
pd.set_option('display.max_rows', None)

# 출력할 최대 열(컬럼) 수를 'None'으로 설정합니다. (선택 사항이지만 함께 설정하는 것이 좋습니다.)
pd.set_option('display.max_columns', None)

# 그래프 색상 무작위 지정
import random
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']
color=colors

# 통계
import scipy.stats as stats

# ============================================================
# ============================================================
# ============================================================

# 스케일링, 폴리노미얼, 라벨인코딩, SMOTE
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.preprocessing import PolynomialFeatures, LabelEncoder
from imblearn.over_sampling import SMOTE

# VIF 계산용
from statsmodels.stats.outliers_influence import variance_inflation_factor

# 단순 선형 회귀(simple linear regression), 다중 선형 회귀(multiple linear regression) 모델 구현
from sklearn.linear_model import LinearRegression  # 선형 회귀
from sklearn.linear_model import SGDRegressor  # 경사하강법
from sklearn.linear_model import Ridge  # 릿지 회귀 : 모든 계수의 제곱합을 추가
from sklearn.linear_model import Lasso  # 라소 회귀 : 모든 계수의 절대값 합을 추가. 계수들을 0에 가깝게 만들고 일부는 0으로 만들어버림.

# 비선형 모델을 선형 모델로 학습할 수 있게 해줌
from sklearn.preprocessing import PolynomialFeatures

# 피어슨 상관계수
from scipy.stats import pearsonr

# 스피어만, 켄달 계수
from scipy.stats import spearmanr, kendalltau

# 모델 성능 평가
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# 데이터 검증
from sklearn.model_selection import train_test_split

# 시퀀스(리스트, 문자열 등) 안에서 각 원소가 몇 번 등장했는지 세주는 빈도 계산 도구 -> 우리는 최빈값 계산할 때 사용
from collections import Counter

# %%
df = pd.read_parquet(r"final.parquet")
print('전체 파일 로드 완료')
# Out:
# 전체 파일 로드 완료
